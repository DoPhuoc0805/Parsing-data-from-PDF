# %%
import pandas as pd
# Out:
#                                          ten_nhiem_vu     don_vi_chu_tri  \
# 0   Xây dựng kế hoạch di trú dữ liệu sau\nkhi chốt...            Sở Y tế
# 1   Đảm bảo hạ tầng theo Sizing, các\ngiải pháp ph...           Sở\nKHCN
# 2   Đảm bảo đường truyền kết nối từ hạ\ntầng triển...           Sở\nKHCN
# 3   Đảm bảo đầu số SMS Brandname\nphục vụ đảm bảo ...           Sở\nKHCN
# 4    Cài đặt Hệ điều hành, K8S hoặc thuê\ngói cài đặt            Sở Y tế
# 5                            Cài đặt CSDL và ứng dụng  Tập đoàn\nViettel
# 6   Phối hợp với Bộ Công An, Bộ\nKHCN đánh giá ATT...            Sở Y tế
# 7   Xây dựng công văn về chuyển dữ\nliệu từ TTDL T...            Sở Y tế
# 8   Thống nhất quy trình tiếp nhận dữ\nliệu, đầu m...            Sở Y tế
# 9   Cập nhật lại dữ liệu từ CSDL được\nTập đoàn Vi...            Sở Y tế
# 10                           Chạy thử và vận hành thử            Sở Y tế
# 11                Ký biên bản kết thúc di trú dữ liệu            Sở Y tế
#
# ...

# %%
t=pd.read_csv(r"C:\GEO\Parsing data from PDF\data\output\cv6582_normalized.csv")
t
# Out:
#                                          ten_nhiem_vu     don_vi_chu_tri  \
# 0   Xây dựng kế hoạch di trú dữ liệu sau\nkhi chốt...            Sở Y tế
# 1   Đảm bảo hạ tầng theo Sizing, các\ngiải pháp ph...           Sở\nKHCN
# 2   Đảm bảo đường truyền kết nối từ hạ\ntầng triển...           Sở\nKHCN
# 3   Đảm bảo đầu số SMS Brandname\nphục vụ đảm bảo ...           Sở\nKHCN
# 4    Cài đặt Hệ điều hành, K8S hoặc thuê\ngói cài đặt            Sở Y tế
# 5                            Cài đặt CSDL và ứng dụng  Tập đoàn\nViettel
# 6   Phối hợp với Bộ Công An, Bộ\nKHCN đánh giá ATT...            Sở Y tế
# 7   Xây dựng công văn về chuyển dữ\nliệu từ TTDL T...            Sở Y tế
# 8   Thống nhất quy trình tiếp nhận dữ\nliệu, đầu m...            Sở Y tế
# 9   Cập nhật lại dữ liệu từ CSDL được\nTập đoàn Vi...            Sở Y tế
# 10                           Chạy thử và vận hành thử            Sở Y tế
# 11                Ký biên bản kết thúc di trú dữ liệu            Sở Y tế
#
# ...

# %%
d=pd.read_csv(r"C:\GEO\Parsing data from PDF\data\output\kh277_normalized.csv")
d
# Out:
#                                          ten_nhiem_vu  \
# 0   Dữ liệu đầu tư công, thu ngân sách, dự án đầu\...
# 1                                   Dữ liệu quy hoạch
# 2              Dữ liệu đất đai, địa chính, môi trường
# 3   Dữ liệu xây dựng, hạ tầng kỹ thuật, giao thông...
# 4                      Hồ sơ, kết quả giải quyết TTHC
# 5         Dữ liệu quản lý văn bản và điều hành (QLVB)
# 6                                        Dữ liệu y tế
# 7                                    Dữ liệu giáo dục
# 8   Đối với khoảng 3,2 triệu thửa đất (đã được đo\...
# 9   Đối với khoảng 950.000 thửa đất còn lại đang\n...
# 10  Tổng rà soát, kiểm kê, đánh giá hiện trạng các...
# 11  Xây dựng, triển khai hệ thống xác thực định\nd...
# 12  Tích hợp Không gian làm việc số HanoiWork\nvới...
# 13  Cung cấp dịch vụ công trực tuyến và đơn giản\n...
# 14  100% hồ sơ phát sinh của nhóm 05 thủ tục giao\...
# 15  Thí điểm miễn cấp phép xây dựng đối với các\nd...
# ...
